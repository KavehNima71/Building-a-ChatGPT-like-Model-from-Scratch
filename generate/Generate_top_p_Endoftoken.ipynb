# %% [markdown]
# # Generate `top_p` `End_Of_token`  `n_rep`

# %%
def generate_top_p(model, tokenizer, prompt, n_rep=3, max_seq_len=256, T=0.9, top_p=0.9, device='cuda', seed=42):
    # Tokenize the prompt and convert it to a tensor on the specified device
    inputs = torch.tensor(tokenizer.encode(prompt).ids, dtype=torch.int, device=device)  # Shape: [T]

    # Repeat the input prompt n_rep times to generate multiple sequences in parallel
    inputs = inputs.unsqueeze(0).repeat(n_rep, 1)  # Shape: [n_rep, T]

    end_token_id = tokenizer.token_to_id('<|endoftext|>')

    model.eval()
    sample_rng = torch.Generator(device=device)
    sample_rng.manual_seed(seed)

    # Track which sequences have finished (hit end token)
    finished = torch.zeros(n_rep, dtype=torch.bool, device=device)

    with torch.no_grad():
        while inputs.shape[-1] < max_seq_len and not all(finished):
            # Forward pass: get logits from the model
            logits = model(inputs)  # Shape: [n_rep, T, vocab_size]

            # Apply softmax to get probabilities for the next token
            probs = torch.softmax(logits[:, -1, :] / T, dim=-1)  # Shape: [n_rep, vocab_size]

            # Select the top_P tokens for each sequence in the batch
            sorted_probs, sorted_indices = torch.sort(probs, descending=True, dim=-1)
            cumulative_probs = torch.cumsum(sorted_probs, dim=-1)

            # Create mask for top-p sampling
            mask = cumulative_probs <= top_p
            # Ensure we always have at least one token
            mask[:, 0] = True

            # Find cutoff indices
            cutoff = mask.sum(dim=-1)

            # Prepare for batched sampling
            sampled_tokens = []
            for i in range(n_rep):
                if finished[i]:
                    # If sequence is finished, just pad with end token
                    sampled_tokens.append(end_token_id)
                    continue

                num_keep = cutoff[i]
                final_probs = sorted_probs[i, :num_keep]
                final_indices = sorted_indices[i, :num_keep]

                # Renormalize probabilities
                final_probs = final_probs / final_probs.sum()

                # Sample one token
                idx = torch.multinomial(final_probs, num_samples=1, generator=sample_rng)
                sampled_token = final_indices[idx]
                sampled_tokens.append(sampled_token)

                # Check if this sequence should finish
                if sampled_token == end_token_id:
                    finished[i] = True

            # Convert sampled tokens to tensor and add to inputs
            sampled_tokens = torch.tensor(sampled_tokens, device=device).unsqueeze(-1)
            inputs = torch.cat((inputs, sampled_tokens), dim=-1)

            # Early exit if all sequences are finished
            if all(finished):
                break

    # Cut off everything after the first occurrence of end_token_id
    final_outputs = []
    for sequence in inputs.tolist():
        if end_token_id in sequence[1:]:
          end_index = sequence[1:].index(end_token_id)
          final_outputs.append(sequence[:end_index+1])
        else:
            final_outputs.append(sequence)

    # Decode all generated sequences
    # generated_texts = tokenizer.decode_batch(inputs.tolist())
    generated_texts = tokenizer.decode_batch(final_outputs)
    return generated_texts

# %%
prompt = 'in last'
generated_texts = generate_top_p(model, tokenizer, prompt, n_rep=3, max_seq_len=256, T=0.9, top_p=0.9, device='cuda', seed=42)
print('Generate top_p End_of_token:')
print()
for i, text in enumerate(generated_texts):
    display(HTML(f"<span style='color: yellow;'>Generated {i+1}:</span> <span style='color: cyan;'>{prompt}</span><span style='color: White;'>{text[len(prompt):]}</span>"))
    print('-'*150)
# Out:
# Generate top_p End_of_token:
# <span style='color: yellow;'>Generated 1:</span> <span style='color: cyan;'>in last</span><span style='color: White;'> night, she took her little car for a walk in the park. She stopped and looked around. It was a big, big playground with swings and slides. Everyone wanted to sit in the swings and play on the swings.
#
# But Anna didn't know what she should do. She looked around and saw a man who was swinging down a bench. He was carrying a bag of glue and she decided to try and put the tape on the box.
#
# She waited and waited, but the man was not there. She was very mad. She asked the man if she could make some lemonade for him. But the man didn't stand was locked it was empty of his apples was too hard work and no one day was gone.
#
#
#
# The man had a big boy didn't open up with a wreck was selling car was broken. Anna had no one day, it was still accident. The chair was there was broken, so much harder. She could not easy and no one day was so much more high up fuller twinkled in the end of another no one day her feetless man was delayed notices who was waiting for a long and the other. Anna was waiting in the last time with her grandparents said yes. He had to go</span>
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# <span style='color: yellow;'>Generated 2:</span> <span style='color: cyan;'>in last</span><span style='color: White;'> night. In the store, one day, a magic fairy appeared. She sent power to the fairy, and gave her a special treat.
#
# From that day on, Kara shared her magic trick with all the other fairies. She was so happy to have her magic wand and make a new friend. And from that day on, she was known as the fairy who had saved her wand.</span>
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# <span style='color: yellow;'>Generated 3:</span> <span style='color: cyan;'>in last</span><span style='color: White;'> night, "I'm gonna go and explore this house!"
#
# Elsie smiled and grabbed her teddy bear. She put it on her head and kept exploring the forest. As she explored, she heard strange noises coming from a nearby tree.
#
# "What are you searching for?" replied Eggie.
#
# "I'm searching!" replied Stella.
#
# The bear smiled and said, "That's a really smart idea. But if you look around, I can find something so special. It's something special. It will help you find it."
#
# Duzzie carefully looked around and saw a big, but she couldn't know two sparkly stars. Aly, just there were still found that day for a magical places he had been hidden and colourful and gasped by the diamond. He was looking for her. With a giant enough magical sights that she had forgotten was even more beautifully wideened that she looked for the secretly intelligent as she never took her fear of the room as she had never said it. She looked for a chance to find a colourfully accepted to gained that night, safe and joyful landsless. She looked for a sparklyengisher. But even more discovery, sparkled in the</span>
# ------------------------------------------------------------------------------------------------------------------------------------------------------
