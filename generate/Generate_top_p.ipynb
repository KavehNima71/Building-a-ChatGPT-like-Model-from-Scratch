# %% [markdown]
# # **Generate** `top_p`

# %%
def generate_top_p(model, tokenizer, prompt, n_rep=3, max_seq_len=128, T=0.9, top_p=0.9, device='cuda', seed=42):
    # Tokenize the prompt and convert it to a tensor on the specified device (e.g., GPU)
    inputs = torch.tensor(tokenizer.encode(prompt).ids, dtype=torch.int, device=device)  # Shape: [T]

    # Repeat the input prompt n_rep times to generate multiple sequences in parallel
    inputs = inputs.unsqueeze(0).repeat(n_rep, 1)  # Shape: [B, T] where B = n_rep

    # Set the model to evaluation mode
    model.eval()

    # Initialize a random number generator for sampling
    sample_rng = torch.Generator(device=device)
    sample_rng.manual_seed(seed)

    # Disable gradient calculation for faster inference
    with torch.no_grad():
        # Continue generating tokens until reaching the maximum sequence length
        while inputs.shape[-1] < max_seq_len:
            # Forward pass: get logits from the model
            logits = model(inputs)  # Shape: [B, T, vocab_size]

            # Apply softmax to get probabilities for the next token
            probs = torch.softmax(logits[:, -1, :] / T, dim=-1)  # Shape: [B, vocab_size]

            # Select the top_P tokens with the highest probabilities
            sorted_probs, sorted_indices = torch.sort(probs, descending=True, dim=-1)  # Shape: [B, top_k]
            cumulative_probs = torch.cumsum(sorted_probs, dim=-1)

            mask = cumulative_probs <= top_p
            mask[:, 0] = True
            cutoff = mask.sum(dim=-1)

            sampled_tokens = []
            for i in range(logits.size(0)):
                num_keep = cutoff[i].item()
                final_probs = sorted_probs[i, :num_keep]
                final_indices = sorted_indices[i, :num_keep]
                final_probs = final_probs / final_probs.sum()

                #Sample one token from the top_k candidates based on their probabilities
                idx = torch.multinomial(final_probs, num_samples=1, generator=sample_rng)
                sampled_token = final_indices[idx]
                sampled_tokens.append(sampled_token)

            ids = torch.stack(sampled_tokens)
            inputs = torch.cat((inputs, ids), dim=-1)  # Shape: [B, T+1]

    # Decode the generated sequences back into text
    generated_text = tokenizer.decode_batch(inputs.tolist())

    return generated_text

# %%
prompt = 'in last'
generated_texts = generate_top_p(model, tokenizer, prompt, n_rep=3, max_seq_len=256, T=0.9, top_p=0.9, device='cuda', seed=42)

print('Generate top_p:')
print()
for i, text in enumerate(generated_texts):
    display(HTML(f"<span style='color: yellow;'>Generated {i+1}:</span> <span style='color: cyan;'>{prompt}</span><span style='color: White;'>{text[len(prompt):]}</span>"))
    print('-'*150)
# Out:
# Generate top_p:
# <span style='color: yellow;'>Generated 1:</span> <span style='color: cyan;'>in last</span><span style='color: White;'> night, she took her little car for a walk in the park. She stopped and looked around. It was a big, big playground with swings and slides. Everyone wanted to sit in the swings and play on the swings.
#
# But Anna didn't know what she should do. She looked around and saw a man who was swinging down a bench. He was carrying a bag of glue and she decided to throw it down.
#
# Then, she saw a boy named Joe walking towards her. Joe asked, "What are you doing with this?" Anna said, "I'm finding my car and my toy car in the park."
#
#
# Joe's mom smiled and said, so she answered from and the park keeper, so many minute. "Lettale King Joe!"
#
# Joe, who was so many care he said, and was so much more enthusiasticly a clever kid's see Sarah's pointie's smile, as he thought she thought for a rushingan. She was a solution, a peaceful mood, but it, he waved to the park was nowhere to the playground, but it, no one direction was more curious and asking, saying that way. He just made him, to all alone, she never at home,</span>
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# <span style='color: yellow;'>Generated 2:</span> <span style='color: cyan;'>in last</span><span style='color: White;'> night. In the store, one day, a magic fairy appeared. She sent power to the fairy, and gave her a special treat.
#
# From that day on, Kara shared her magic trick with all the other fairies. She was so happy to have her magic wand and make a new friend. And from that day on, she was known as the fairy who had saved her wand.Once upon a time, there was a little girl named Lily. She loved to play outside in the sunshine. One day, she saw a squirrel and picked it up. She showed it to her mommy and said, "Look, Mommy, I want you can I can I can I have a squirrel!"
#
#
# Lily, but I have a fox." Aar upset do not sure a squirrel. But if it was no longer did not sure her toys are'tâ€™sredso named it was no one cold air ranger. Lily, but it came to me?" A steal!" She didn't open the tree. Lily. Lily. The butterfly was uncomfortable looking at me can't for a fire was so much more scared me think the thorns. Lily. I couldn't for a drainenganting right't open up in return! She</span>
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# <span style='color: yellow;'>Generated 3:</span> <span style='color: cyan;'>in last</span><span style='color: White;'> night, "I'm gonna go and explore this house!"
#
# Elsie smiled and grabbed her teddy bear. She put it on her head and kept exploring the forest. As she explored, she heard strange noises coming from a nearby tree.
#
# "What are you searching for?" replied Eggie.
#
# "I'm searching!" replied Stella.
#
# The bear smiled and said, "I'll help you. Follow me!"
#
# She followed the bear through the forest until they finally reached the hut. She was so excited! She opened the door and found herself in the forest. She was so found her way up in the whole place with a smile-card yard, there were surrounded her bed, safe and she had found the birds and her favourite hopped in the hay castle. She was so much further than she was standing in her fun her dream of the heart was surrounded her adventure she was her best embracendit old!
#
#
#
#
#
# She went as she was hiding. She found herself in the biggest and heard by the world of the whole- May waved her joy with her family members of her favourite kind friends. But, the most wide back yard. She was so much more artist</span>
# ------------------------------------------------------------------------------------------------------------------------------------------------------
